# %%
import pandas as pd

# %%
URL = "https://ru.wikipedia.org/wiki/%D0%A1%D0%BF%D0%B8%D1%81%D0%BE%D0%BA_%D1%81%D1%82%D0%B0%D0%BD%D1%86%D0%B8%D0%B9_%D0%9C%D0%BE%D1%81%D0%BA%D0%BE%D0%B2%D1%81%D0%BA%D0%BE%D0%B3%D0%BE_%D0%BC%D0%B5%D1%82%D1%80%D0%BE%D0%BF%D0%BE%D0%BB%D0%B8%D1%82%D0%B5%D0%BD%D0%B0"

# %%
data = pd.read_html(URL, attrs={"class": "standard sortable"})
data[0]
# Out:
#      Unnamed: 0                  Название станции Прежние названия  \
# 0           NaN  Бульвар Рокоссовского Улица Подбельского (с 01...
# 1           NaN                                       Черкизовская
# 2           NaN                             Преображенская площадь
# 3           NaN                                         Сокольники
# 4           NaN                                     Красносельская
# ..          ...                                                ...
# 245         NaN                                      Юго-Восточная
# 246         NaN                                             Косино
# 247         NaN                                Улица Дмитриевского
# 248         NaN                                       Лухмановская
# 249         NaN                                         Некрасовка
#
#        Дата открытия Пере- садки Глубина, м[1]  \
# 0     1 августа 1990         NaN            −8
# 1     1 августа 1990         NaN            −9
# 2    31 декабря 1965         NaN            −8
# 3        15 мая 1935         NaN            −9
# 4        15 мая 1935         NaN            −8
# ..               ...         ...           ...
# 245    27 марта 2020         NaN           −20
# 246      3 июня 2019         NaN           −27
# 247      3 июня 2019         NaN           −18
# 248      3 июня 2019         NaN           −15
# 249      3 июня 2019         NaN           −16
#
#                               Тип конструкции  \
# 0    колонная мелкого заложения трёхпролётная
# 1             односводчатая мелкого заложения
# 2    колонная мелкого заложения трёхпролётная
# 3    колонная мелкого заложения трёхпролётная
# 4    колонная мелкого заложения двухпролётная
# ..                                        ...
# 245  колонная мелкого заложения двухпролётная
# 246  колонная мелкого заложения трёхпролётная
# 247  колонная мелкого заложения двухпролётная
# 248  колонная мелкого заложения трёхпролётная
# 249  колонная мелкого заложения двухпролётная
#
#                             Координаты  Вид станции
# 0    55°48′53″ с. ш. 37°44′03″ в. д.HЯ          NaN
# 1    55°48′14″ с. ш. 37°44′41″ в. д.HЯ          NaN
# 2    55°47′47″ с. ш. 37°42′54″ в. д.HЯ          NaN
# 3    55°47′20″ с. ш. 37°40′49″ в. д.HЯ          NaN
# 4    55°46′48″ с. ш. 37°40′02″ в. д.HЯ          NaN
# ..                                 ...          ...
# 245  55°42′19″ с. ш. 37°49′05″ в. д.HЯ          NaN
# 246  55°42′12″ с. ш. 37°51′04″ в. д.HЯ          NaN
# 247  55°42′37″ с. ш. 37°52′48″ в. д.HЯ          NaN
# 248  55°42′31″ с. ш. 37°54′03″ в. д.HЯ          NaN
# 249  55°42′10″ с. ш. 37°55′42″ в. д.HЯ          NaN
#
# [250 rows x 8 columns]
